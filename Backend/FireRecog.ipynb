# %% [markdown]
# **Vào Runtime -> Chọn Change runtime -> Chọn T4 GPU**

# %%
# !nvidia-smi

import os
HOME = os.getcwd()
# Out:
# Wed May 29 09:59:24 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# change "/content/gdrive/MyDrive/"  to "/mydrive"
# !ln -s /content/gdrive/MyDrive/ /mydrive
# Out:
# Mounted at /content/gdrive

# %%
# !pip install gdown

# %%
# !gdown --id 14fswp310Rpt2yvSL8sk94-xMCbHDAJZp -O /content/continuous_fire.v6-original_raw-images.yolov8.zip
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=14fswp310Rpt2yvSL8sk94-xMCbHDAJZp
# From (redirected): https://drive.google.com/uc?id=14fswp310Rpt2yvSL8sk94-xMCbHDAJZp&confirm=t&uuid=809fbd3f-c82b-4dd8-b290-a394e62906d4
# To: /content/continuous_fire.v6-original_raw-images.yolov8.zip
# 100% 222M/222M [00:03<00:00, 57.4MB/s]

# %%
# !mkdir Fire
# !unzip /content/continuous_fire.v6-original_raw-images.yolov8.zip -d Fire
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: Fire/train/labels/Img_1256_jpg.rf.ed56f66d8b8416468bc10de26b6a2c4e.txt
#  extracting: Fire/train/labels/Img_1257_jpg.rf.0fa9399c08b14bb36393d335a7775881.txt
#  extracting: Fire/train/labels/Img_1258_jpg.rf.1287dd9856ca750454a02b076e14d756.txt
#  extracting: Fire/train/labels/Img_1259_jpg.rf.3a4d8749cb7d682f338c7efd043cc695.txt
#  extracting: Fire/train/labels/Img_1259_jpg.rf.e1bd36e9105a167c10661c9b950edc41.txt
#  extracting: Fire/train/labels/Img_1259_jpg.rf.ff043df68e69fa5db3f8756e0b443186.txt
#  extracting: Fire/train/labels/Img_125_jpg.rf.f4837b78d626f6fd1376839375ff9058.txt
#  extracting: Fire/train/labels/Img_1260_jpg.rf.086f78ba67b8a6845b2b6e418a1a4a98.txt
#  extracting: Fire/train/labels/Img_1260_jpg.rf.9201327cc3e470e583d3684a1ac5370c.txt
#  extracting: Fire/train/labels/Img_1261_jpg.rf.3e2934435fcec4f5068600976aac6cd3.txt
#  extracting: Fire/train/labels/Img_1261_jpg.rf.b24015cb5ef6bceeb435e01c97d2ca36.txt
# ...

# %%
# Pip install method (recommended)

# !pip install ultralytics --quiet

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.2.24 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.4/78.2 GB disk)

# %% [markdown]
# **Vào folder Fire, mở file data.yaml, copy path của folder images trong từng folder train, valid, test vào các dòng tương ứng trong file data.yaml**

# %%
# !yolo task=detect mode=train model=/content/runs/detect/train/weights/best.pt data=/content/Fire/data.yaml epochs=15 imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.2.25 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.24 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/Fire/data.yaml
# Out:
# Ultralytics YOLOv8.2.24 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127519 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/Fire/valid/labels.cache... 1018 images, 0 backgrounds, 0 corrupt: 100% 1018/1018 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 64/64 [00:25<00:00,  2.50it/s]
#                    all       1018       2099      0.817      0.616      0.735      0.432
#                      0       1018        643      0.908      0.725      0.873      0.507
#                      2       1018        992      0.776      0.421      0.552      0.281
#                      3       1018          2      0.767          1      0.995      0.697
#                      4       1018        462      0.817      0.319       0.52      0.243
# Speed: 1.5ms preprocess, 9.4ms inference, 0.0ms loss, 4.4ms postprocess per image
# Results saved to runs/detect/val
# ...

# %% [markdown]
# **Predict: Test thử model đã chạy được chưa**

# %%
# !yolo predict model=/content/runs/detect/train/weights/best.pt source='https://production-media.paperswithcode.com/datasets/fd43ecf0-5472-47c3-868e-29d12fb245c2.jpg'
# Out:
# Ultralytics YOLOv8.2.24 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127519 parameters, 0 gradients, 28.4 GFLOPs
#
# ...
# 100% 707k/707k [00:00<00:00, 4.00MB/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# image 1/1 /content/fd43ecf0-5472-47c3-868e-29d12fb245c2.jpg: 640x480 1 2, 76.5ms
# Speed: 4.1ms preprocess, 76.5ms inference, 1333.4ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=/content/runs/detect/train/weights/best.pt source='https://bloximages.chicago2.vip.townnews.com/theeagle.com/content/tncms/assets/v3/editorial/b/9e/b9eb58fe-693a-11e5-acad-cb2d7e2e9d39/560ed93b27d21.image.jpg'
# Out:
# /bin/bash: line 1: yolo: command not found

# %% [markdown]
# **Tải model đã train về**
